# %% [markdown]
# PREDICTING DIABETES USING LINEAR REGRESSION IN PYTHON

# %%
#import libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error

# %%
#import dataset
df = pd.read_csv ("C:\\Users\\georg\\Desktop\\diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 763    False
# 764    False
# 765    False
# 766    False
# 767    False
# Length: 768, dtype: bool

# %%
df.Glucose.unique()
# Out:
# array([148,  85, 183,  89, 137, 116,  78, 115, 197, 125, 110, 168, 139,
#        189, 166, 100, 118, 107, 103, 126,  99, 196, 119, 143, 147,  97,
#        145, 117, 109, 158,  88,  92, 122, 138, 102,  90, 111, 180, 133,
#        106, 171, 159, 146,  71, 105, 101, 176, 150,  73, 187,  84,  44,
#        141, 114,  95, 129,  79,   0,  62, 131, 112, 113,  74,  83, 136,
#         80, 123,  81, 134, 142, 144,  93, 163, 151,  96, 155,  76, 160,
#        124, 162, 132, 120, 173, 170, 128, 108, 154,  57, 156, 153, 188,
#        152, 104,  87,  75, 179, 130, 194, 181, 135, 184, 140, 177, 164,
#         91, 165,  86, 193, 191, 161, 167,  77, 182, 157, 178,  61,  98,
#        127,  82,  72, 172,  94, 175, 195,  68, 186, 198, 121,  67, 174,
#        199,  56, 169, 149,  65, 190], dtype=int64)

# %%
df.Glucose = df.Glucose.replace(0,int(df.Glucose.mean()))

# %%
df.Glucose.unique()
# Out:
# array([148,  85, 183,  89, 137, 116,  78, 115, 197, 125, 110, 168, 139,
#        189, 166, 100, 118, 107, 103, 126,  99, 196, 119, 143, 147,  97,
#        145, 117, 109, 158,  88,  92, 122, 138, 102,  90, 111, 180, 133,
#        106, 171, 159, 146,  71, 105, 101, 176, 150,  73, 187,  84,  44,
#        141, 114,  95, 129,  79, 120,  62, 131, 112, 113,  74,  83, 136,
#         80, 123,  81, 134, 142, 144,  93, 163, 151,  96, 155,  76, 160,
#        124, 162, 132, 173, 170, 128, 108, 154,  57, 156, 153, 188, 152,
#        104,  87,  75, 179, 130, 194, 181, 135, 184, 140, 177, 164,  91,
#        165,  86, 193, 191, 161, 167,  77, 182, 157, 178,  61,  98, 127,
#         82,  72, 172,  94, 175, 195,  68, 186, 198, 121,  67, 174, 199,
#         56, 169, 149,  65, 190], dtype=int64)

# %%
df.BloodPressure.unique()
# Out:
# array([ 72,  66,  64,  40,  74,  50,   0,  70,  96,  92,  80,  60,  84,
#         30,  88,  90,  94,  76,  82,  75,  58,  78,  68, 110,  56,  62,
#         85,  86,  48,  44,  65, 108,  55, 122,  54,  52,  98, 104,  95,
#         46, 102, 100,  61,  24,  38, 106, 114], dtype=int64)

# %%
df.BloodPressure.replace(0,df.BloodPressure.median(), inplace=True)

# %%
df.BloodPressure.unique()
# Out:
# array([ 72,  66,  64,  40,  74,  50,  70,  96,  92,  80,  60,  84,  30,
#         88,  90,  94,  76,  82,  75,  58,  78,  68, 110,  56,  62,  85,
#         86,  48,  44,  65, 108,  55, 122,  54,  52,  98, 104,  95,  46,
#        102, 100,  61,  24,  38, 106, 114], dtype=int64)

# %%
df.SkinThickness.unique()
# Out:
# array([35, 29,  0, 23, 32, 45, 19, 47, 38, 30, 41, 33, 26, 15, 36, 11, 31,
#        37, 42, 25, 18, 24, 39, 27, 21, 34, 10, 60, 13, 20, 22, 28, 54, 40,
#        51, 56, 14, 17, 50, 44, 12, 46, 16,  7, 52, 43, 48,  8, 49, 63, 99],
#       dtype=int64)

# %%
df.SkinThickness.replace(0,df.SkinThickness.median(), inplace=True)

# %%
df.SkinThickness. unique()
# Out:
# array([35, 29, 23, 32, 45, 19, 47, 38, 30, 41, 33, 26, 15, 36, 11, 31, 37,
#        42, 25, 18, 24, 39, 27, 21, 34, 10, 60, 13, 20, 22, 28, 54, 40, 51,
#        56, 14, 17, 50, 44, 12, 46, 16,  7, 52, 43, 48,  8, 49, 63, 99],
#       dtype=int64)

# %%
df.Insulin.unique()
# Out:
# array([  0,  94, 168,  88, 543, 846, 175, 230,  83,  96, 235, 146, 115,
#        140, 110, 245,  54, 192, 207,  70, 240,  82,  36,  23, 300, 342,
#        304, 142, 128,  38, 100,  90, 270,  71, 125, 176,  48,  64, 228,
#         76, 220,  40, 152,  18, 135, 495,  37,  51,  99, 145, 225,  49,
#         50,  92, 325,  63, 284, 119, 204, 155, 485,  53, 114, 105, 285,
#        156,  78, 130,  55,  58, 160, 210, 318,  44, 190, 280,  87, 271,
#        129, 120, 478,  56,  32, 744, 370,  45, 194, 680, 402, 258, 375,
#        150,  67,  57, 116, 278, 122, 545,  75,  74, 182, 360, 215, 184,
#         42, 132, 148, 180, 205,  85, 231,  29,  68,  52, 255, 171,  73,
#        108,  43, 167, 249, 293,  66, 465,  89, 158,  84,  72,  59,  81,
#        196, 415, 275, 165, 579, 310,  61, 474, 170, 277,  60,  14,  95,
#        237, 191, 328, 250, 480, 265, 193,  79,  86, 326, 188, 106,  65,
#        166, 274,  77, 126, 330, 600, 185,  25,  41, 272, 321, 144,  15,
# ...

# %%
df.Insulin.replace(0,df.Insulin.median(), inplace=True)

# %%
df.Insulin.unique()
# Out:
# array([ 30.5,  94. , 168. ,  88. , 543. , 846. , 175. , 230. ,  83. ,
#         96. , 235. , 146. , 115. , 140. , 110. , 245. ,  54. , 192. ,
#        207. ,  70. , 240. ,  82. ,  36. ,  23. , 300. , 342. , 304. ,
#        142. , 128. ,  38. , 100. ,  90. , 270. ,  71. , 125. , 176. ,
#         48. ,  64. , 228. ,  76. , 220. ,  40. , 152. ,  18. , 135. ,
#        495. ,  37. ,  51. ,  99. , 145. , 225. ,  49. ,  50. ,  92. ,
#        325. ,  63. , 284. , 119. , 204. , 155. , 485. ,  53. , 114. ,
#        105. , 285. , 156. ,  78. , 130. ,  55. ,  58. , 160. , 210. ,
#        318. ,  44. , 190. , 280. ,  87. , 271. , 129. , 120. , 478. ,
#         56. ,  32. , 744. , 370. ,  45. , 194. , 680. , 402. , 258. ,
#        375. , 150. ,  67. ,  57. , 116. , 278. , 122. , 545. ,  75. ,
#         74. , 182. , 360. , 215. , 184. ,  42. , 132. , 148. , 180. ,
#        205. ,  85. , 231. ,  29. ,  68. ,  52. , 255. , 171. ,  73. ,
# ...

# %%
df.BMI.unique()
# Out:
# array([33.6, 26.6, 23.3, 28.1, 43.1, 25.6, 31. , 35.3, 30.5,  0. , 37.6,
#        38. , 27.1, 30.1, 25.8, 30. , 45.8, 29.6, 43.3, 34.6, 39.3, 35.4,
#        39.8, 29. , 36.6, 31.1, 39.4, 23.2, 22.2, 34.1, 36. , 31.6, 24.8,
#        19.9, 27.6, 24. , 33.2, 32.9, 38.2, 37.1, 34. , 40.2, 22.7, 45.4,
#        27.4, 42. , 29.7, 28. , 39.1, 19.4, 24.2, 24.4, 33.7, 34.7, 23. ,
#        37.7, 46.8, 40.5, 41.5, 25. , 25.4, 32.8, 32.5, 42.7, 19.6, 28.9,
#        28.6, 43.4, 35.1, 32. , 24.7, 32.6, 43.2, 22.4, 29.3, 24.6, 48.8,
#        32.4, 38.5, 26.5, 19.1, 46.7, 23.8, 33.9, 20.4, 28.7, 49.7, 39. ,
#        26.1, 22.5, 39.6, 29.5, 34.3, 37.4, 33.3, 31.2, 28.2, 53.2, 34.2,
#        26.8, 55. , 42.9, 34.5, 27.9, 38.3, 21.1, 33.8, 30.8, 36.9, 39.5,
#        27.3, 21.9, 40.6, 47.9, 50. , 25.2, 40.9, 37.2, 44.2, 29.9, 31.9,
#        28.4, 43.5, 32.7, 67.1, 45. , 34.9, 27.7, 35.9, 22.6, 33.1, 30.4,
#        52.3, 24.3, 22.9, 34.8, 30.9, 40.1, 23.9, 37.5, 35.5, 42.8, 42.6,
# ...

# %%
df.BMI= df.BMI.replace(0,int(df.BMI.mean()))

# %%
df.BMI.unique()
# Out:
# array([33.6, 26.6, 23.3, 28.1, 43.1, 25.6, 31. , 35.3, 30.5, 37.6, 38. ,
#        27.1, 30.1, 25.8, 30. , 45.8, 29.6, 43.3, 34.6, 39.3, 35.4, 39.8,
#        29. , 36.6, 31.1, 39.4, 23.2, 22.2, 34.1, 36. , 31.6, 24.8, 19.9,
#        27.6, 24. , 33.2, 32.9, 38.2, 37.1, 34. , 40.2, 22.7, 45.4, 27.4,
#        42. , 29.7, 28. , 39.1, 19.4, 24.2, 24.4, 33.7, 34.7, 23. , 37.7,
#        46.8, 40.5, 41.5, 25. , 25.4, 32.8, 32.5, 42.7, 19.6, 28.9, 28.6,
#        43.4, 35.1, 32. , 24.7, 32.6, 43.2, 22.4, 29.3, 24.6, 48.8, 32.4,
#        38.5, 26.5, 19.1, 46.7, 23.8, 33.9, 20.4, 28.7, 49.7, 39. , 26.1,
#        22.5, 39.6, 29.5, 34.3, 37.4, 33.3, 31.2, 28.2, 53.2, 34.2, 26.8,
#        55. , 42.9, 34.5, 27.9, 38.3, 21.1, 33.8, 30.8, 36.9, 39.5, 27.3,
#        21.9, 40.6, 47.9, 50. , 25.2, 40.9, 37.2, 44.2, 29.9, 31.9, 28.4,
#        43.5, 32.7, 67.1, 45. , 34.9, 27.7, 35.9, 22.6, 33.1, 30.4, 52.3,
#        24.3, 22.9, 34.8, 30.9, 40.1, 23.9, 37.5, 35.5, 42.8, 42.6, 41.8,
# ...

# %%
df.DiabetesPedigreeFunction.unique()
# Out:
# array([0.627, 0.351, 0.672, 0.167, 2.288, 0.201, 0.248, 0.134, 0.158,
#        0.232, 0.191, 0.537, 1.441, 0.398, 0.587, 0.484, 0.551, 0.254,
#        0.183, 0.529, 0.704, 0.388, 0.451, 0.263, 0.205, 0.257, 0.487,
#        0.245, 0.337, 0.546, 0.851, 0.267, 0.188, 0.512, 0.966, 0.42 ,
#        0.665, 0.503, 1.39 , 0.271, 0.696, 0.235, 0.721, 0.294, 1.893,
#        0.564, 0.586, 0.344, 0.305, 0.491, 0.526, 0.342, 0.467, 0.718,
#        0.962, 1.781, 0.173, 0.304, 0.27 , 0.699, 0.258, 0.203, 0.855,
#        0.845, 0.334, 0.189, 0.867, 0.411, 0.583, 0.231, 0.396, 0.14 ,
#        0.391, 0.37 , 0.307, 0.102, 0.767, 0.237, 0.227, 0.698, 0.178,
#        0.324, 0.153, 0.165, 0.443, 0.261, 0.277, 0.761, 0.255, 0.13 ,
#        0.323, 0.356, 0.325, 1.222, 0.179, 0.262, 0.283, 0.93 , 0.801,
#        0.207, 0.287, 0.336, 0.247, 0.199, 0.543, 0.192, 0.588, 0.539,
#        0.22 , 0.654, 0.223, 0.759, 0.26 , 0.404, 0.186, 0.278, 0.496,
# ...

# %%
df.Age.unique()
# Out:
# array([50, 31, 32, 21, 33, 30, 26, 29, 53, 54, 34, 57, 59, 51, 27, 41, 43,
#        22, 38, 60, 28, 45, 35, 46, 56, 37, 48, 40, 25, 24, 58, 42, 44, 39,
#        36, 23, 61, 69, 62, 55, 65, 47, 52, 66, 49, 63, 67, 72, 81, 64, 70,
#        68], dtype=int64)

# %%
#Data Analysis: Correlation and heatmap
df_corr=df.corr()
sns.heatmap(df_corr, annot=True, cmap="RdYlGn")
# Out:
# <AxesSubplot:>

# %%
#Data Analysis: Pairplot
sns.pairplot(df)

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.128022       0.208615       0.032568
# Glucose                      0.128022  1.000000       0.218698       0.172312
# BloodPressure                0.208615  0.218698       1.000000       0.147809
# SkinThickness                0.032568  0.172312       0.147809       1.000000
# Insulin                     -0.055697  0.357197      -0.028721       0.238188
# BMI                          0.021500  0.232581       0.280664       0.547774
# DiabetesPedigreeFunction    -0.033523  0.137158      -0.002378       0.142977
# Age                          0.544341  0.266673       0.324915       0.054514
# Outcome                      0.221898  0.492884       0.165723       0.189065
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.055697  0.021500                 -0.033523
# ...

# %%
#Assign x and y variables
x = df.drop('Outcome', axis=1)
y = df['Outcome']

#split data into train/test set (80/20) and shuffle
x_train,x_test, y_train, y_test = train_test_split(x,y, test_size=0.30, shuffle= True)

#Assign algorithm
model= LinearRegression()

#Link algorithm to x and y variables
model.fit(x_train, y_train)

#Find y_intercepts
model.intercept_
# Out:
# -1.0695430975068345

# %%
#Find x coefficients
model.coef_
# Out:
# array([ 0.02988071,  0.00657477, -0.00107397, -0.00046613, -0.00013637,
#         0.0180983 ,  0.07229209, -0.00024106])

# %%
#Checking the performance of the model
mae_train = mean_absolute_error(y_train, model.predict(x_train))
print("training set Mean Absolute Error:%.2f" %mae_train)

mae_test = mean_absolute_error(y_test, model.predict(x_test))
print("testing set Mean Absolute Error:%.2f" %mae_test)
# Out:
# training set Mean Absolute Error:0.32
# testing set Mean Absolute Error:0.34
